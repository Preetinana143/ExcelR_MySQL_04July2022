# %% [markdown]
# <a href="https://colab.research.google.com/github/Preetinana143/ExcelR_MySQL_04July2022/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
movies = pd.read_csv("/content/Movie-Ratings.csv")
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe() #Statistics
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movies.rename(columns = {"Year of release":"Year", "Audience Ratings %":"AudienceRating", "Rotten Tomatoes Ratings %": "CriticRating", "Budget (million $)":"Budget"}, inplace=True)

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  Budget  \
# 0  (500) Days of Summer      Comedy            87              81       8
# 1            10,000 B.C.  Adventure             9              44     105
# 2             12 Rounds      Action            30              52      20
# 3              127 Hours  Adventure            93              84      18
# 4              17 Again      Comedy            55              70      20
#
#    Year
# 0  2009
# 1  2008
# 2  2009
# 3  2010
# 4  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   Budget          559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   Budget          559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(1), int64(3), object(2)
# memory usage: 22.7+ KB

# %%
import seaborn as sns

# %%
sns.jointplot(data=movies, x='CriticRating', y='AudienceRating')

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(movies.CriticRating, bins=15)
# Out:
# (array([19., 32., 51., 41., 46., 41., 47., 38., 47., 28., 37., 32., 42.,
#         29., 29.]),
#  array([ 0.        ,  6.46666667, 12.93333333, 19.4       , 25.86666667,
#         32.33333333, 38.8       , 45.26666667, 51.73333333, 58.2       ,
#         64.66666667, 71.13333333, 77.6       , 84.06666667, 90.53333333,
#         97.        ]),
#  <a list of 15 Patch objects>)

# %%
plt.hist([movies[movies.Genre=='Action'].Budget, movies[movies.Genre=='Drama'].Budget,movies[movies.Genre=='Thriller'].Budget], bins=15, stacked = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# (array([[ 9., 39., 24., 13., 16.,  9.,  8., 14.,  5.,  4.,  8.,  2.,  2.,
#           0.,  1.],
#         [48., 80., 35., 19., 18., 10.,  8., 15.,  5.,  4.,  8.,  2.,  2.,
#           0.,  1.],
#         [52., 94., 39., 24., 20., 14.,  9., 16.,  5.,  5.,  8.,  2.,  2.,
#           0.,  1.]]),
#  array([  0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180., 200.,
#         220., 240., 260., 280., 300.]),
#  <a list of 3 Lists of Patches objects>)

# %%
plt.show()

# %%
movies.Genre = movies.Genre.astype('category')

# %%
list1 = list()
mylabels=list()
for gen in movies.Genre.cat.categories:
  list1.append(movies[movies.Genre == gen].Budget)
  mylabels.append(gen)

plt.hist(list1, bins=15, stacked = True, label=mylabels)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
sns.boxplot(data = movies, x = 'Genre', y = 'CriticRating')

# %%
sns.boxplot(data = movies, x = 'Genre', y = 'AudienceRating')

# %%
sns.violinplot(data = movies, x = 'Genre', y = 'AudienceRating')

# %%
c = sns.FacetGrid(movies, row= 'Genre', col = 'Year', hue = 'Genre')

# %%
c = c.map(plt.scatter, 'CriticRating', 'AudienceRating')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-90126b37b4ab> in <module>
# ----> 1 c = c.map(plt.scatter, 'CriticRating', 'AudienceRating')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     684             # Get the current axis
#     685             modify_state = not func_module.startswith("seaborn")
# --> 686             ax = self.facet_axis(row_i, col_j, modify_state)
#     687
#     688             # Decide what color to plot with
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in facet_axis(self, row_i, col_j, modify_state)
#     826         # Get a reference to the axes object we want, and make it active
#     827         if modify_state:
# --> 828             plt.sca(ax)
#     829         return ax
#     830
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in sca(ax)
#     856             m.canvas.figure.sca(ax)
#     857             return
# --> 858     raise ValueError("Axes instance argument was not found in a figure")
#     859
#     860
#
# ValueError: Axes instance argument was not found in a figure

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-c1ad447edee0> in <module>
# ----> 1 plt.hist(movies.CriticRating, bins=15)
#
# NameError: name 'plt' is not defined

# %%
sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind='hex')
